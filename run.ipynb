# %% [markdown]
# # Run on Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# from "235"
# %cd /content/drive/MyDrive/Colab Notebooks/Colab Notebooks/1.Diary
# Out:
# /content/drive/.shortcut-targets-by-id/1aLG9bDpm9reJvJpFfIcdhdM3rCMOU790/Colab Notebooks/1.Diary

# %%
# !cat app.py
# Out:
# # !pip install Flask
# # pip install Flask
#
# from flask import Flask, request, render_template
# import os
#
#
# app = Flask(__name__)
#
# diary_entries = {}
#
# @app.route('/')
# def index():
#   return render_template('index.html', entries=diary_entries)
#
# @app.route('/add_entry', methods=['POST'])
# def add_entry():
#   data = request.form['date']
#   entry = request.form['entry']
#   diary_entries[date] = entry
#   return render_template('index.html', entries=diary_entries)
#
# if __name__ == '__main__':
#   # app.run(debug=True)
#   app.run(host='0.0.0.0', port=5000)

# %%
# !pip install Flask

# %%
# !python app.py
# Out:
#  * Serving Flask app 'app'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# Press CTRL+C to quit
# ^C
